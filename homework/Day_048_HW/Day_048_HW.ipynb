# %%
import os
import copy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns # 另一個繪圖-樣式套件

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn import metrics

# %%
dir_data = 'D:/Document/GitHub/3rd-ML100Days/homework/Day_048_HW/data'
f_X_data = os.path.join(dir_data, 'train.csv')
X_data = pd.read_csv(f_X_data, header=-1)
X_data.describe()
# Out:
#                 0            1            2            3            4   \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      0.025596    -0.024526    -0.024088    -0.002271     1.092329
# std       1.008282     1.016298     0.979109     0.970575     4.538834
# min      -3.365711    -3.492086    -2.695602    -3.460471   -16.421901
# 25%      -0.669010    -0.693937    -0.698830    -0.617557    -1.801997
# 50%       0.027895    -0.033194     0.008145     0.002327     0.862818
# 75%       0.762520     0.682753     0.661434     0.640743     3.843172
# max       3.326246     3.583870     2.546507     3.088738    17.565345
#
#                 5            6            7            8            9   ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000  ...
# mean     -0.006250     0.497342    -0.037883     0.026391    -0.003597  ...
# std       0.989128     2.118819     2.232256     1.001064     1.013520  ...
# ...

# %%
# 印出NULL欄位
for c in X_data.columns:
    if X_data[c].isnull().sum() > 0:
        print(c, X_data[c].isnull().sum())

# %%
f_Y_data = os.path.join(dir_data, 'trainLabels.csv')
Y_data = pd.read_csv(f_Y_data, header=-1)
Y_data.describe()
# Out:
#                 0
# count  1000.00000
# mean      0.51000
# std       0.50015
# min       0.00000
# 25%       0.00000
# 50%       1.00000
# 75%       1.00000
# max       1.00000

# %%
X_mm = MinMaxScaler().fit_transform(X_data)
X_train, X_test, Y_train, Y_test = train_test_split(X_mm, Y_data, test_size=.25, random_state = 4)

# %%
rfc = RandomForestClassifier()
n_estimators = [100, 200, 300]
max_depth = [10, 20, 30, 50]
param_grid = dict(n_estimators = n_estimators, max_depth = max_depth)

grid_search = GridSearchCV(gbc, param_grid, scoring='f1', n_jobs=-1, verbose=1)
grid_result = grid_search.fit(X_train, Y_train)
print('Best Accuracy is %f using %s' %(grid_result.best_score_, grid_result.best_params_))
# Out:
# D:\tool\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:    3.3s finished
# D:\tool\Anaconda3\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Accuracy is 0.794273 using {'max_depth': 50, 'n_estimators': 100}

# %%
# rfc = [RandomForestClassifier(max_depth=10, n_estimators = 100),
#        RandomForestClassifier(max_depth=10, n_estimators = 200),
#        RandomForestClassifier(max_depth=10, n_estimators = 300),
#        RandomForestClassifier(max_depth=20, n_estimators = 100),
#        RandomForestClassifier(max_depth=20, n_estimators = 200),
#        RandomForestClassifier(max_depth=20, n_estimators = 300)]
# for i in range(len(rfc)):
#     scores  =  cross_val_score ( rfc[i] ,  X_train ,  Y_train ,  cv = 10 ,  scoring = 'accuracy' ) 
#     print(scores)
#     print('accuracy score:', scores.mean())

# %%
gbc = GradientBoostingClassifier()

n_estimators = [100, 200, 300]
max_depth = [1, 3, 5]
param_grid = dict(n_estimators = n_estimators, max_depth = max_depth)

grid_search = GridSearchCV(gbc, param_grid, scoring='f1', n_jobs=-1, verbose=1)
grid_result = grid_search.fit(X_train, Y_train)
print('Best Accuracy is %f using %s' %(grid_result.best_score_, grid_result.best_params_))
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# D:\tool\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  27 | elapsed:    0.4s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    2.2s finished
# D:\tool\Anaconda3\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Accuracy is 0.873042 using {'max_depth': 5, 'n_estimators': 300}

# %%
clf = GradientBoostingClassifier(max_depth=5, n_estimators = 300)
clf.fit(X_train, Y_train)
Y_pred = clf.predict(X_test)
f1 = metrics.f1_score(Y_test,Y_pred)
print('f1-score:', f1)
# Out:
# D:\tool\Anaconda3\lib\site-packages\sklearn\ensemble\gradient_boosting.py:1450: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# f1-score: 0.9068825910931174
